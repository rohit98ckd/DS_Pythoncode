# %% [markdown]
# <a href="https://colab.research.google.com/github/rohit98ckd/DS_Pythoncode/blob/main/chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 48.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 105.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 26.1 MB/s eta 0:00:00
# ...

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("facebook/blenderbot-400M-distill")

model = AutoModelForSeq2SeqLM.from_pretrained("facebook/blenderbot-400M-distill")

# %%
print("Type \"q\" to quit")
while True:
    message = input("MESSAGE: ")
    if message in ["", "q", "quit"]:
        break
    inputs = tokenizer([message], return_tensors='pt')
    reply_ids = model.generate(**inputs)
    print(f"Sarah:     {tokenizer.batch_decode(reply_ids, skip_special_tokens=True)[0]}")
# Out:
# Type "q" to quit
# MESSAGE: hi
# /usr/local/lib/python3.9/dist-packages/transformers/generation/utils.py:1273: UserWarning: Neither `max_length` nor `max_new_tokens` has been set, `max_length` will default to 60 (`generation_config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Blenderbot 2.0 response:      Hi! How are you? I just got back from walking my dog. Do you have any pets?
# MESSAGE: what is ur name
# Blenderbot 2.0 response:      Her name is Linda. She's a rescue dog. I rescued her when she was a puppy.
# MESSAGE: i love u
# Blenderbot 2.0 response:      I love you too.  I hope you have a great day.  What are you up to?
# MESSAGE: who the fuck are you ?
# Blenderbot 2.0 response:      I'm not sure, but I'm sure I'll find out when I get home from work.
# ...
