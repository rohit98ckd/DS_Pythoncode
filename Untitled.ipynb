# %%
# !pip install pyresparser
# Out:
# ...
#      ---------------------------------------- 4.2/4.2 MB 797.4 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.7/1.7 MB 3.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 5.6/5.6 MB 2.9 MB/s eta 0:00:00
# ...
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dell\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dell\anaconda3\lib\site-packages)
# ...

# %%
# !pip install PyPDF2
# Out:
# ...
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dell\anaconda3\lib\site-packages)
# ...
#      -------------------------------------- 232.6/232.6 kB 1.8 MB/s eta 0:00:00
# ...

# %%
# !pip install python-docx
# Out:
# ...
#      ---------------------------------------- 5.6/5.6 MB 3.9 MB/s eta 0:00:00
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dell\anaconda3\lib\site-packages)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...

# %%
# !pip install docx2txt
# Out:
# ...
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dell\anaconda3\lib\site-packages)

# %%
import os

# %%
import PyPDF2

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 3A3B-B1C3
#
#  Directory of C:\Users\Dell\EXCELR\Resume Classification NLP Project
#
# 01-03-2023  23:27    <DIR>          .
# 01-03-2023  22:32    <DIR>          ..
# 01-03-2023  22:34    <DIR>          .ipynb_checkpoints
# 01-03-2023  22:33            19,021 Reactjs Developer_MD Khizaruddin Rauf _Musquare Technologies.docx
# 01-03-2023  22:33           112,917 Reactjs Developer_Prabakaran_Musquare Technologies.pdf
# 01-03-2023  23:27            27,480 Untitled.ipynb
#                3 File(s)        159,418 bytes
#                3 Dir(s)  123,509,571,584 bytes free

# %%
pdffileobj =open("Reactjs Developer_Prabakaran_Musquare Technologies.pdf","rb")

# %%
pdfreader = PyPDF2.PdfReader(pdffileobj)

# %%
pageobj = pdfreader.pages(0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [47], in <cell line: 1>()
# ----> 1 pageobj = pdfreader.pages(0)
#
# TypeError: '_VirtualList' object is not callable

# %%
import docx

# %%
doc = docx.Document('Reactjs Developer_MD Khizaruddin Rauf _Musquare Technologies.docx')

# %%
for i in range(100):
    print(doc.paragraphs[i].text)
# Out:
# MD KHIZARUDDIN RAUF
#  	 EXPERIENCE
#
# ⇨ Currently working in PickupBiz Solution Private Limited, Pune from January 2021 to till date
# ⇨ 9 Months of working as an Intern on UI React JS - Software Developer
# ⇨ Having sound experience and exposure on UI development using React JS, Bootstrap, HTML 5, CSS, React Hooks, and Redux etc.
# ⇨ Ability to work under any given environment
# ⇨ Demonstrated good communication and Analytical skills
# ⇨ Team building skills, emphasizing versatility and adaptability
# ⇨ Dedication and drive as a hard-working individual
# ⇨ Ability to manage multiple tasks in a pressured environment
#
# Application Development & UI Designing –
#  Coordinated with the development team of 10 to discuss user interface ideas and applications. - Reviewed application requirements and interface designs to ensure compatibility with existing applications.
#
# UI Components Designing & Application Interface Coding –
# ...

# %%
for para in doc.paragraphs:
    print(para.text)
# Out:
# MD KHIZARUDDIN RAUF
#  	 EXPERIENCE
#
# ⇨ Currently working in PickupBiz Solution Private Limited, Pune from January 2021 to till date
# ⇨ 9 Months of working as an Intern on UI React JS - Software Developer
# ⇨ Having sound experience and exposure on UI development using React JS, Bootstrap, HTML 5, CSS, React Hooks, and Redux etc.
# ⇨ Ability to work under any given environment
# ⇨ Demonstrated good communication and Analytical skills
# ⇨ Team building skills, emphasizing versatility and adaptability
# ⇨ Dedication and drive as a hard-working individual
# ⇨ Ability to manage multiple tasks in a pressured environment
#
# Application Development & UI Designing –
#  Coordinated with the development team of 10 to discuss user interface ideas and applications. - Reviewed application requirements and interface designs to ensure compatibility with existing applications.
#
# UI Components Designing & Application Interface Coding –
# ...

# %%
import docx2txt

# %%
txt = docx2txt.process("D:\EXCELR\Resume Classification NLP project\Resumes\Reactjs Developer_MD Khizaruddin Rauf _Musquare Technologies.docx")

# %%
txt
# Out:
# 'MD KHIZARUDDIN RAUF \n\n \t EXPERIENCE \n\n     \n\n⇨ Currently working in PickupBiz Solution Private Limited, Pune from January 2021 to till date \n\n⇨ 9 Months of working as an Intern on UI React JS - Software Developer \n\n⇨ Having sound experience and exposure on UI development using React JS, Bootstrap, HTML 5, CSS, React Hooks, and Redux etc. \n\n⇨ Ability to work under any given environment \n\n⇨ Demonstrated good communication and Analytical skills \n\n⇨ Team building skills, emphasizing versatility and adaptability \n\n⇨ Dedication and drive as a hard-working individual \n\n⇨ Ability to manage multiple tasks in a pressured environment \n\n                                                                           \n\nApplication Development & UI Designing – \n\n Coordinated with the development team of 10 to discuss user interface ideas and applications. - Reviewed application requirements and interface designs to ensure compatibility with existing applications.  \n\n \n\nUI
# ...

# %%
txt.replace('\t', ' ')
# Out:
# 'MD KHIZARUDDIN RAUF \n\n   EXPERIENCE \n\n     \n\n⇨ Currently working in PickupBiz Solution Private Limited, Pune from January 2021 to till date \n\n⇨ 9 Months of working as an Intern on UI React JS - Software Developer \n\n⇨ Having sound experience and exposure on UI development using React JS, Bootstrap, HTML 5, CSS, React Hooks, and Redux etc. \n\n⇨ Ability to work under any given environment \n\n⇨ Demonstrated good communication and Analytical skills \n\n⇨ Team building skills, emphasizing versatility and adaptability \n\n⇨ Dedication and drive as a hard-working individual \n\n⇨ Ability to manage multiple tasks in a pressured environment \n\n                                                                           \n\nApplication Development & UI Designing – \n\n Coordinated with the development team of 10 to discuss user interface ideas and applications. - Reviewed application requirements and interface designs to ensure compatibility with existing applications.  \n\n \n\nUI 
# ...

# %%
txt.split("\n")
# Out:
# ['MD KHIZARUDDIN RAUF ',
#  '',
#  ' \t EXPERIENCE ',
#  '',
#  '     ',
#  '',
#  '⇨ Currently working in PickupBiz Solution Private Limited, Pune from January 2021 to till date ',
#  '',
#  '⇨ 9 Months of working as an Intern on UI React JS - Software Developer ',
#  '',
#  '⇨ Having sound experience and exposure on UI development using React JS, Bootstrap, HTML 5, CSS, React Hooks, and Redux etc. ',
#  '',
#  '⇨ Ability to work under any given environment ',
#  '',
#  '⇨ Demonstrated good communication and Analytical skills ',
#  '',
#  '⇨ Team building skills, emphasizing versatility and adaptability ',
#  '',
#  '⇨ Dedication and drive as a hard-working individual ',
#  '',
#  '⇨ Ability to manage multiple tasks in a pressured environment ',
#  '',
#  '                                                                           ',
#  '',
#  'Application Development & UI Designing – ',
#  '',
# ...

# %%
for line in txt.split("\n"):
    print(line)
# Out:
# MD KHIZARUDDIN RAUF
#
#  	 EXPERIENCE
#
#
#
# ⇨ Currently working in PickupBiz Solution Private Limited, Pune from January 2021 to till date
#
# ⇨ 9 Months of working as an Intern on UI React JS - Software Developer
#
# ⇨ Having sound experience and exposure on UI development using React JS, Bootstrap, HTML 5, CSS, React Hooks, and Redux etc.
#
# ⇨ Ability to work under any given environment
#
# ⇨ Demonstrated good communication and Analytical skills
#
# ⇨ Team building skills, emphasizing versatility and adaptability
#
# ⇨ Dedication and drive as a hard-working individual
#
# ⇨ Ability to manage multiple tasks in a pressured environment
#
#
#
# Application Development & UI Designing –
#
#  Coordinated with the development team of 10 to discuss user interface ideas and applications. - Reviewed application requirements and interface designs to ensure compatibility with existing applications.
#
#
#
# UI Components Designing & Application Interface Coding –
#
# ...

# %%
txt.split("\n")[0].strip()
print(txt)
# Out:
# MD KHIZARUDDIN RAUF
#
#  	 EXPERIENCE
#
#
#
# ⇨ Currently working in PickupBiz Solution Private Limited, Pune from January 2021 to till date
#
# ⇨ 9 Months of working as an Intern on UI React JS - Software Developer
#
# ⇨ Having sound experience and exposure on UI development using React JS, Bootstrap, HTML 5, CSS, React Hooks, and Redux etc.
#
# ⇨ Ability to work under any given environment
#
# ⇨ Demonstrated good communication and Analytical skills
#
# ⇨ Team building skills, emphasizing versatility and adaptability
#
# ⇨ Dedication and drive as a hard-working individual
#
# ⇨ Ability to manage multiple tasks in a pressured environment
#
#
#
# Application Development & UI Designing –
#
#  Coordinated with the development team of 10 to discuss user interface ideas and applications. - Reviewed application requirements and interface designs to ensure compatibility with existing applications.
#
#
#
# UI Components Designing & Application Interface Coding –
#
# ...

# %%
" ".join(txt)
# Out:
# 'M D   K H I Z A R U D D I N   R A U F   \n \n   \t   E X P E R I E N C E   \n \n           \n \n ⇨   C u r r e n t l y   w o r k i n g   i n   P i c k u p B i z   S o l u t i o n   P r i v a t e   L i m i t e d ,   P u n e   f r o m   J a n u a r y   2 0 2 1   t o   t i l l   d a t e   \n \n ⇨   9   M o n t h s   o f   w o r k i n g   a s   a n   I n t e r n   o n   U I   R e a c t   J S   -   S o f t w a r e   D e v e l o p e r   \n \n ⇨   H a v i n g   s o u n d   e x p e r i e n c e   a n d   e x p o s u r e   o n   U I   d e v e l o p m e n t   u s i n g   R e a c t   J S ,   B o o t s t r a p ,   H T M L   5 ,   C S S ,   R e a c t   H o o k s ,   a n d   R e d u x   e t c .   \n \n ⇨   A b i l i t y   t o   w o r k   u n d e r   a n y   g i v e n   e n v i r o n m e n t   \n \n ⇨   D e m o n s t r a t e d   g o o d   c o m m u n i c a t i o n   a n d   A n a l y t i c a l   s k i l l s   \n \n ⇨   T e a m   b u i l d i n g   s k i l l s ,   e m p h a s i z i n g   v e r s a t 
# ...

# %%
temp = docx2txt.process("D:\EXCELR\Resume Classification NLP project\Resumes\Reactjs Developer_MD Khizaruddin Rauf _Musquare Technologies.docx")

text = [line.replace('\t', ' ') for line in temp.split('\n') if line]

# %%
text
# Out:
# ['MD KHIZARUDDIN RAUF ',
#  '   EXPERIENCE ',
#  '     ',
#  '⇨ Currently working in PickupBiz Solution Private Limited, Pune from January 2021 to till date ',
#  '⇨ 9 Months of working as an Intern on UI React JS - Software Developer ',
#  '⇨ Having sound experience and exposure on UI development using React JS, Bootstrap, HTML 5, CSS, React Hooks, and Redux etc. ',
#  '⇨ Ability to work under any given environment ',
#  '⇨ Demonstrated good communication and Analytical skills ',
#  '⇨ Team building skills, emphasizing versatility and adaptability ',
#  '⇨ Dedication and drive as a hard-working individual ',
#  '⇨ Ability to manage multiple tasks in a pressured environment ',
#  '                                                                           ',
#  'Application Development & UI Designing – ',
# ...

# %%
def extract_text_from_doc(doc_path):
    temp = docx2txt.process(doc_path)
    text = [line.replace('\t', ' ') for line in temp.split('\n') if line]
    return ' '.join(text)

# %%
extract_text_from_doc("D:\EXCELR\Resume Classification NLP project\Resumes\Reactjs Developer_MD Khizaruddin Rauf _Musquare Technologies.docx")
# Out:
# 'MD KHIZARUDDIN RAUF     EXPERIENCE        ⇨ Currently working in PickupBiz Solution Private Limited, Pune from January 2021 to till date  ⇨ 9 Months of working as an Intern on UI React JS - Software Developer  ⇨ Having sound experience and exposure on UI development using React JS, Bootstrap, HTML 5, CSS, React Hooks, and Redux etc.  ⇨ Ability to work under any given environment  ⇨ Demonstrated good communication and Analytical skills  ⇨ Team building skills, emphasizing versatility and adaptability  ⇨ Dedication and drive as a hard-working individual  ⇨ Ability to manage multiple tasks in a pressured environment                                                                              Application Development & UI Designing –   Coordinated with the development team of 10 to discuss user interface ideas and applications. - Reviewed application requirements and interface designs to ensure compatibility with existing applications.     UI Components Designing & Application Interface 
# ...

# %%
import os

with os.scandir("D:\EXCELR\Resume Classification NLP project\Resumes") as entries:
    for entry in entries:
        print(entry.name)
# Out:
# Internship_Ravali_Musquare Technologies (1).docx
# Internship_Susovan Bag_Musquare Technologies.docx
# Peoplesoft resumes
# React Developer_Deepakreddy.docx
# React Developer_Haripriya.docx
# React Developer_Kamalakar Reddy.docx
# React Developer_Naveen sadhu.docx
# React Developer_PavasGoswami.doc
# React Developer_Pragnya.docx
# React Developer_Sarala Madasu-converted.docx
# React Developer_Thirupathiamma.docx
# React Developer_Vinay Reddy.doc
# React Dev_Krishna Kanth.docx
# React Dev_Krishna Kanth_Musquare Technologies.docx
# React JS Developer_AnjaniPriyadarshini.doc
# React JS Developer_KotaniDurgaprasad[3_1] (1)-converted.docx
# React JS Developer_Venkatalakshmi (1)-converted.docx
# Reactjs Developer_kambala sai surendra_Musquare Technologies.docx
# Reactjs Developer_M Lokesh Babu_Musquare Technologies.docx
# Reactjs Developer_M Lokesh.docx
# Reactjs Developer_MD Khizaruddin Rauf _Musquare Technologies.docx
# Reactjs Developer_Prabakaran_Musquare Technologies.pdf
# ...

# %%
file = os.scandir("D:\EXCELR\Resume Classification NLP project\Resumes")

# %%
with os.scandir("D:\EXCELR\Resume Classification NLP project\Resumes\Peoplesoft resumes") as entries:
    for entry in entries:
        print(entry)
# Out:
# <DirEntry 'Peoplesoft Admin_AnubhavSingh.docx'>
# <DirEntry 'Peoplesoft Admin_G Ananda Rayudu.doc'>
# <DirEntry 'Peoplesoft Admin_Gangareddy.doc'>
# <DirEntry 'Peoplesoft Admin_Murali.docx'>
# <DirEntry 'Peoplesoft Admin_Priyanka Ramadoss.doc'>
# <DirEntry 'Peoplesoft Admin_SirazuddinMohammad.docx'>
# <DirEntry 'Peoplesoft Admin_srinivasarao.doc'>
# <DirEntry 'Peoplesoft Admin_Varkala Vikas.docx'>
# <DirEntry 'Peoplesoft Admin_Vinod Akkala.doc'>
# <DirEntry 'PeopleSoft DBA_Ganesh Alladi.doc'>
# <DirEntry 'PeopleSoft DBA_Vivekanand Sayana.docx'>
# <DirEntry 'Peoplesoft Finance_Arun Venu.doc'>
# <DirEntry 'Peoplesoft Finance_Pritam Biswas.doc'>
# <DirEntry 'Peoplesoft Finance_Rahul Ahuja.doc'>
# <DirEntry 'Peoplesoft FSCM_HariNarayana.docx'>
# <DirEntry 'Peoplesoft FSCM_Murali.docx'>
# <DirEntry 'Peoplesoft FSCM_PriyabrataHota.docx'>
# <DirEntry 'Peoplesoft FSCM_R Ahmed.doc'>
# <DirEntry 'Peoplesoft FSCM_SUJATHA.docx'>
# <DirEntry 'Resume_Subha Santosh_Peoplesoft FSCM.docx'>

# %%
path = "D:\EXCELR\Resume Classification NLP project\Resumes"

# %%
os.scandir(path)

# %%
len(os.listdir())
# Out:
# 27

# %%
for file in os.listdir():
    if file.endswith(".docx"):
        print(file)
len(file)
# Out:
# Internship_Ravali_Musquare Technologies (1).docx
# Internship_Susovan Bag_Musquare Technologies.docx
# React Developer_Deepakreddy.docx
# React Developer_Haripriya.docx
# React Developer_Kamalakar Reddy.docx
# React Developer_Naveen sadhu.docx
# React Developer_Pragnya.docx
# React Developer_Sarala Madasu-converted.docx
# React Developer_Thirupathiamma.docx
# React Dev_Krishna Kanth.docx
# React Dev_Krishna Kanth_Musquare Technologies.docx
# React JS Developer_KotaniDurgaprasad[3_1] (1)-converted.docx
# React JS Developer_Venkatalakshmi (1)-converted.docx
# Reactjs Developer_kambala sai surendra_Musquare Technologies.docx
# Reactjs Developer_M Lokesh Babu_Musquare Technologies.docx
# Reactjs Developer_M Lokesh.docx
# Reactjs Developer_MD Khizaruddin Rauf _Musquare Technologies.docx
# Reactjs Developer_Pranish Sonone_Musquare Technologies.docx
# Reactjs Developer_Ranga Gaganam_Musquare Technologies.docx
# Reactjs Developer_Shaik Abdul Sharuk_Musquare Technologies.docx
# 15

# %%
data=[]
for file in os.listdir():
    if file.endswith(".docx"):
        resume=extract_text_from_doc(file)
        data.append(resume)

# %%
len(data)
# Out:
# 20

# %%
df=pd.DataFrame(data,columns=["resumes"])
df
# Out:
#                                               resumes
# 0   Name: Ravali P                                ...
# 1   SUSOVAN  BAG    Seeking  a  challenging  posit...
# 2   Kanumuru Deepak Reddy   CAREER OBJECTIVE: To s...
# 3   HARIPRIYA BATTINA  Experience as UI Developer ...
# 4   KAMALAKAR REDDY. A  Linked In: https://www.lin...
# 5   Naveen Sadhu Title: software developer        ...
# 6   PRAGNYA PATTNAIK        Expertise:    Having a...
# 7   SARALA MADASU SARALA MADASU  204,Sri geethika...
# 8   Thirupathamma Balla SUMMARY: 2.8 year of IT ex...
# 9   Ui-Developer/ React JS Developer  NAME: KRISHN...
# 10  Ui-Developer/ React JS Developer  NAME: KRISHN...
# 11  Kotani Durga Prasad Objective: Aspirant for a ...
# 12  Venkatalakshmi Pedireddy Software Developer Ex...
# 13  KAMBALA SAI SURENDRA          SUMMARY    PROJE...
# 14  MAREEDU LOKESH BABU PROFESSIONAL OVERVIEW     ...
# 15  MAREEDU LOKESH BABU PROFESSIONAL OVERVIEW     ...
# ...

# %%
df["Catagory"]="Peoplesoft"
df
# Out:
#                                               resumes    Catagory
# 0   Name: Ravali P                                ...  Peoplesoft
# 1   SUSOVAN  BAG    Seeking  a  challenging  posit...  Peoplesoft
# 2   Kanumuru Deepak Reddy   CAREER OBJECTIVE: To s...  Peoplesoft
# 3   HARIPRIYA BATTINA  Experience as UI Developer ...  Peoplesoft
# 4   KAMALAKAR REDDY. A  Linked In: https://www.lin...  Peoplesoft
# 5   Naveen Sadhu Title: software developer        ...  Peoplesoft
# 6   PRAGNYA PATTNAIK        Expertise:    Having a...  Peoplesoft
# 7   SARALA MADASU SARALA MADASU  204,Sri geethika...  Peoplesoft
# 8   Thirupathamma Balla SUMMARY: 2.8 year of IT ex...  Peoplesoft
# 9   Ui-Developer/ React JS Developer  NAME: KRISHN...  Peoplesoft
# 10  Ui-Developer/ React JS Developer  NAME: KRISHN...  Peoplesoft
# 11  Kotani Durga Prasad Objective: Aspirant for a ...  Peoplesoft
# 12  Venkatalakshmi Pedireddy Software Developer Ex...  Peoplesoft
# ...

# %%
# Import Module
import os
  
# Folder Path
path = "D:\EXCELR\Resume Classification NLP project\Resumes"
  
# Change the directory
os.scandir(path)
 
dff=[]
# Read text File
  
def extract_text_from_doc(doc_path):
    temp = docx2txt.process(doc_path)
    text = [line.replace('\t', ' ') for line in temp.split('\n') if line]
    return ' '.join(text)
  
# iterate through all file
for file in os.listdir():
    # Check whether file is in text format or not
    if file.endswith(".docx"):
        file_path = f"{path}\{file}"
          
        resume=extract_text_from_doc(file)
        dff.append(resume)
rdf=pd.DataFrame(dff,columns=["Resumes"])  
rdf["Catagory"]="Peoplesoft"
rdf
# Out:
#                                               Resumes    Catagory
# 0   Name: Ravali P                                ...  Peoplesoft
# 1   SUSOVAN  BAG    Seeking  a  challenging  posit...  Peoplesoft
# 2   Kanumuru Deepak Reddy   CAREER OBJECTIVE: To s...  Peoplesoft
# 3   HARIPRIYA BATTINA  Experience as UI Developer ...  Peoplesoft
# 4   KAMALAKAR REDDY. A  Linked In: https://www.lin...  Peoplesoft
# 5   Naveen Sadhu Title: software developer        ...  Peoplesoft
# 6   PRAGNYA PATTNAIK        Expertise:    Having a...  Peoplesoft
# 7   SARALA MADASU SARALA MADASU  204,Sri geethika...  Peoplesoft
# 8   Thirupathamma Balla SUMMARY: 2.8 year of IT ex...  Peoplesoft
# 9   Ui-Developer/ React JS Developer  NAME: KRISHN...  Peoplesoft
# 10  Ui-Developer/ React JS Developer  NAME: KRISHN...  Peoplesoft
# 11  Kotani Durga Prasad Objective: Aspirant for a ...  Peoplesoft
# 12  Venkatalakshmi Pedireddy Software Developer Ex...  Peoplesoft
# ...

# %%
import csv

# %%
with open("resume_peoplefile.csv", 'w') as csvfile: 
    # creating a csv writer object 
    csvwriter = csv.writer(csvfile) 
        
    # writing the fields 
    csvwriter.writerow(["resume"])
    csvwriter.writerow(data)

# %%
import pandas as pd
